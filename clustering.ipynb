# %% [markdown]
# # Clustering

# %% [markdown]
# # Setup dependencies
# I will be using pandas and sklearn for managing data and machine learning.
# <details>
#     <summary>pip install...</summary>
#
# ```python
# # Allows to install a python package
# pip install package-name
# # or install python package with a specific version
# pip install package-name==version
# ```
# </details>

# %% [markdown]
# !pip install pandas
# !pip install scikit-learn

# %%
# Used to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %% [markdown]
# # Generating synthetic dataset

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

CLUSTERS=10
x, y = make_blobs(n_samples=400, centers=CLUSTERS, cluster_std=0.9, random_state=10)

# %% [markdown]
# # Applying K-means clustering

# %%
kmeans = KMeans(n_clusters=CLUSTERS)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=10)

# %% [markdown]
# # Cluster centers

# %%
kmeans.cluster_centers_
# Out:
# array([[ 8.34796799,  4.10997778],
#        [-6.60462803, -8.26804469],
#        [ 4.33960575, -4.28788833],
#        [-5.73173773,  5.09262832],
#        [-9.99500718,  0.1502649 ],
#        [ 2.80795574,  4.78438321],
#        [ 5.54955038, -9.56206087],
#        [-0.13104959, -5.44726602],
#        [ 3.74272371,  8.99020894],
#        [ 6.1380871 ,  2.5455478 ]])

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

y_pred = model.predict(x_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       4 from sklearn.metrics import recall_score
#       5 from sklearn.metrics import f1_score
# ----> 7 y_pred = model.predict(x_test)
#       9 conf_matrix = confusion_matrix(y_test, y_pred)
#      10 print("Confusion Matrix:")
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Key Metrics Derived from the Confusion Matrix
#
# |                | Formula | Explanation |
# |----------------|--------------------|--------------------|
# | **Accuracy** | $\frac{TP + TN}{TP + TN + FP + FN}$ | The proportion of correctly classified instances out of the total instances.  |
# | **Precision** |  $\frac{TP}{TP + FP}$ | The proportion of positive predictions that are actually correct. |
# | **Recall** |  $\frac{TP}{TP + FN}$ | The proportion of actual positives that are correctly predicted. |
# | **Specificity** |  $\frac{TN}{TN + FP}$ | The proportion of actual negatives that are correctly predicted. |
# | **F1-Score** | $2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}$  | The harmonic mean of precision and recall. |

# %% [markdown]
# ### Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# %% [markdown]
# ### Precision

# %%
precision = precision_score(y_test, y_pred)
print(f"Precision: {precision:.2f}")

# %% [markdown]
# ### Recall

# %%
recall = recall_score(y_test, y_pred)
print(f"Recall: {recall:.2f}")

# %% [markdown]
# ### F1 Score

# %%
f1 = f1_score(y_test, y_pred)
print(f"F1-Score: {f1:.2f}")

# %%
report = classification_report(y_test, y_pred)
print("Classification Report:")
print(report)

# %% [markdown]
# # Plot the clusters and cluster centers

# %%
# Ploting data points
plt.scatter(x[:, 0], x[:, 1], c=kmeans.labels_, cmap='viridis')

# Ploting data centers
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='+', s=400, color='white')

plt.show()
